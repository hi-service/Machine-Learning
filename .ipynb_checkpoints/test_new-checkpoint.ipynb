# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, GlobalMaxPooling1D

# %%
# Data
data = {
    'gejala': [
        'tidak bisa dinyalakan',
        'mesin mengeluarakan bau',
        'bunyi mesin aneh',
        'bergetar tidak normal',
        'motor panas berlebihan',
        'mengeluarkan bunyi berdecit',
        'rem tidak berfungsi',
        'motor tersendat sendat',
        'oli mengalami kebocoran',
        'overheat pada mesin',
        'warna asap putih',
        'bunyi mesin aneh',
        'motor berbunyi knocking',
        'turunnya performa mesin',
        'getaran tidak normal',
        'keluar bercak oli',
        'pengurangan level oli',
        'kebocoran blok mesin',
        'mesin tidak befungsi',
        'kondisi aki melemah',
        'lampu indikator menyala',
        'mesin sulit dihidupkan',
        'stater berbunyi aneh',
        'mesin mati mendadak',
        'mesin bergetar kuat',
        'getaran pada kemudi',
        'berisik saat berkendara',
        'warna asap hitam',
        'bau asap aneh',
        'mesin tidak berdaya',
        'berbunyi saat mengerem',
        'rem terasa licin',
        'kecepatan rem melemah',
        'terdapat gesekan gigi',
        'sulit memindahkan gigi',
        'transmisi berbunyi aneh',
        # Tambahkan gejala lain sesuai kebutuhan
    ],
    'kerusakan': [
        'Mesin',
        'Mesin',
        'Mesin',
        'Kelistrikan',
        'Kelistrikan',
        'Kelistrikan',
        'Sistem Rem',
        'Sistem Rem',
        'Sistem Rem',
        'Overheat',
        'Overheat',
        'Overheat',
        'bunyi ketukan pada mesin',
        'bunyi ketukan pada mesin',
        'bunyi ketukan pada mesin',
        'kebocoran minyak',
        'kebocoran minyak',
        'kebocoran minyak',
        'kegagalan aki',
        'kegagalan aki',
        'kegagalan aki',
        'masalah saat menyala',
        'masalah saat menyala',
        'masalah saat menyala',
        'getaran berlebihan',
        'getaran berlebihan',
        'getaran berlebihan',
        'asap dari knalpot',
        'asap dari knalpot',
        'asap dari knalpot',
        'masalah pengereman',
        'masalah pengereman',
        'masalah pengereman',
        'masalah transmisi',
        'masalah transmisi',
        'masalah transmisi',
        # Tambahkan label lain sesuai kebutuhan
    ]
}

df = pd.DataFrame(data)
df.head()
# Out:
#                     gejala    kerusakan
# 0    tidak bisa dinyalakan        Mesin
# 1  mesin mengeluarakan bau        Mesin
# 2         bunyi mesin aneh        Mesin
# 3    bergetar tidak normal  Kelistrikan
# 4   motor panas berlebihan  Kelistrikan

# %%
# Membagi data menjadi training dan testing sets
train_data, test_data = train_test_split(df, test_size=0.2, random_state=42)

# Tokenisasi teks
tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_data['gejala'])
vocab_size = len(tokenizer.word_index) + 1

# Mengonversi teks menjadi sequences
X_train = tokenizer.texts_to_sequences(train_data['gejala'])
X_test = tokenizer.texts_to_sequences(test_data['gejala'])

# Padding sequences agar memiliki panjang yang sama
maxlen = max(len(seq) for seq in X_train + X_test)
X_train_padded = pad_sequences(X_train, padding='pre', maxlen=maxlen) #NOTE
X_test_padded = pad_sequences(X_test, padding='pre', maxlen=maxlen)

# Label encoding untuk kolom target
label_to_index = {label: i for i, label in enumerate(df['kerusakan'].unique())}
y_train = train_data['kerusakan'].map(label_to_index)
y_test = test_data['kerusakan'].map(label_to_index)

# %%
# Membuat model
model = Sequential()
model.add(Embedding(vocab_size, 100, input_length=maxlen))
model.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(len(label_to_index), activation='softmax'))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()

# Melatih model
model.fit(X_train_padded, y_train, epochs=50, validation_data=(X_test_padded, y_test), batch_size=32)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 3, 100)            5300
#
#  lstm (LSTM)                 (None, 128)               117248
#
#  dense (Dense)               (None, 12)                1548
#
# =================================================================
# Total params: 124,096
# Trainable params: 124,096
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 1/1 [==============================] - 7s 7s/step - loss: 2.4875 - accuracy: 0.0357 - val_loss: 2.4857 - val_accuracy: 0.1250
# Epoch 2/50
# 1/1 [==============================] - 0s 101ms/step - loss: 2.4813 - accuracy: 0.1071 - val_loss: 2.4887 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 1/1 [==============================] - 0s 113ms/step - loss: 2.4765 - accuracy: 0.2500 - val_loss: 2.4918 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 1/1 [==============================] - 0s 113ms/step - loss: 2.4723 - accuracy: 0.2500 - val_loss: 2.4949 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 1/1 [==============================] - 0s 98ms/step - loss: 2.4652 - accuracy: 0.2857 - val_loss: 2.4981 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 1/1 [==============================] - 0s 101ms/step - loss: 2.4585 - accuracy: 0.4643 - val_loss: 2.5014 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 1/1 [==============================] - 0s 94ms/step - loss: 2.4541 - accuracy: 0.5000 - val_loss: 2.5049 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 1/1 [==============================] - 0s 123ms/step - loss: 2.4472 - accuracy: 0.4643 - val_loss: 2.5084 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 1/1 [==============================] - 0s 108ms/step - loss: 2.4416 - accuracy: 0.5000 - val_loss: 2.5121 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 1/1 [==============================] - 0s 95ms/step - loss: 2.4359 - accuracy: 0.5714 - val_loss: 2.5159 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 1/1 [==============================] - 0s 102ms/step - loss: 2.4298 - accuracy: 0.5714 - val_loss: 2.5199 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 1/1 [==============================] - 0s 105ms/step - loss: 2.4223 - accuracy: 0.6429 - val_loss: 2.5241 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 1/1 [==============================] - 0s 108ms/step - loss: 2.4118 - accuracy: 0.6429 - val_loss: 2.5284 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 1/1 [==============================] - 0s 109ms/step - loss: 2.4048 - accuracy: 0.6429 - val_loss: 2.5330 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 1/1 [==============================] - 0s 106ms/step - loss: 2.3930 - accuracy: 0.6071 - val_loss: 2.5379 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 1/1 [==============================] - 0s 134ms/step - loss: 2.3885 - accuracy: 0.6071 - val_loss: 2.5430 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 1/1 [==============================] - 0s 189ms/step - loss: 2.3760 - accuracy: 0.6429 - val_loss: 2.5483 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 1/1 [==============================] - 0s 172ms/step - loss: 2.3673 - accuracy: 0.6429 - val_loss: 2.5540 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 1/1 [==============================] - 0s 118ms/step - loss: 2.3553 - accuracy: 0.6786 - val_loss: 2.5599 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 1/1 [==============================] - 0s 119ms/step - loss: 2.3433 - accuracy: 0.6071 - val_loss: 2.5662 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 1/1 [==============================] - 0s 105ms/step - loss: 2.3266 - accuracy: 0.6786 - val_loss: 2.5729 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 1/1 [==============================] - 0s 163ms/step - loss: 2.3155 - accuracy: 0.6071 - val_loss: 2.5799 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 1/1 [==============================] - 0s 189ms/step - loss: 2.3030 - accuracy: 0.6429 - val_loss: 2.5873 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 1/1 [==============================] - 0s 151ms/step - loss: 2.2848 - accuracy: 0.6429 - val_loss: 2.5952 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 1/1 [==============================] - 0s 117ms/step - loss: 2.2653 - accuracy: 0.6786 - val_loss: 2.6036 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 1/1 [==============================] - 0s 103ms/step - loss: 2.2492 - accuracy: 0.6786 - val_loss: 2.6126 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 1/1 [==============================] - 0s 169ms/step - loss: 2.2284 - accuracy: 0.7143 - val_loss: 2.6221 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 1/1 [==============================] - 0s 184ms/step - loss: 2.2069 - accuracy: 0.6786 - val_loss: 2.6323 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 1/1 [==============================] - 0s 122ms/step - loss: 2.1815 - accuracy: 0.6786 - val_loss: 2.6430 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 1/1 [==============================] - 0s 132ms/step - loss: 2.1597 - accuracy: 0.6786 - val_loss: 2.6544 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 1/1 [==============================] - 0s 114ms/step - loss: 2.1304 - accuracy: 0.6786 - val_loss: 2.6665 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 1/1 [==============================] - 0s 129ms/step - loss: 2.1020 - accuracy: 0.6786 - val_loss: 2.6793 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 1/1 [==============================] - 0s 115ms/step - loss: 2.0606 - accuracy: 0.6786 - val_loss: 2.6929 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 1/1 [==============================] - 0s 98ms/step - loss: 2.0321 - accuracy: 0.6429 - val_loss: 2.7073 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 1/1 [==============================] - 0s 98ms/step - loss: 1.9878 - accuracy: 0.6429 - val_loss: 2.7226 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 1/1 [==============================] - 0s 95ms/step - loss: 1.9660 - accuracy: 0.6786 - val_loss: 2.7388 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 1/1 [==============================] - 0s 93ms/step - loss: 1.9151 - accuracy: 0.6786 - val_loss: 2.7558 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 1/1 [==============================] - 0s 129ms/step - loss: 1.8782 - accuracy: 0.6786 - val_loss: 2.7737 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 1/1 [==============================] - 0s 161ms/step - loss: 1.8282 - accuracy: 0.6786 - val_loss: 2.7922 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 1/1 [==============================] - 0s 174ms/step - loss: 1.7687 - accuracy: 0.7143 - val_loss: 2.8113 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 1/1 [==============================] - 0s 217ms/step - loss: 1.7347 - accuracy: 0.6429 - val_loss: 2.8309 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 1/1 [==============================] - 0s 188ms/step - loss: 1.6689 - accuracy: 0.7143 - val_loss: 2.8506 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 1/1 [==============================] - 0s 123ms/step - loss: 1.6191 - accuracy: 0.6786 - val_loss: 2.8704 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 1/1 [==============================] - 0s 129ms/step - loss: 1.5676 - accuracy: 0.6786 - val_loss: 2.8897 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 1/1 [==============================] - 0s 113ms/step - loss: 1.5018 - accuracy: 0.7143 - val_loss: 2.9079 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 1/1 [==============================] - 0s 125ms/step - loss: 1.4460 - accuracy: 0.7143 - val_loss: 2.9245 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 1/1 [==============================] - 0s 101ms/step - loss: 1.3885 - accuracy: 0.6786 - val_loss: 2.9397 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 1/1 [==============================] - 0s 139ms/step - loss: 1.3278 - accuracy: 0.7143 - val_loss: 2.9531 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 1/1 [==============================] - 0s 167ms/step - loss: 1.2715 - accuracy: 0.7143 - val_loss: 2.9651 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 1/1 [==============================] - 0s 169ms/step - loss: 1.2296 - accuracy: 0.7500 - val_loss: 2.9754 - val_accuracy: 0.0000e+00

# %%
import tkinter as tk
from tkinter import ttk
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Assume label_to_index is defined during training
label_to_index = {label: i for i, label in enumerate(df['kerusakan'].unique())}

# Fungsi untuk mengonversi teks menjadi sequence
def text_to_sequence(text):
    sequence = tokenizer.texts_to_sequences([text])
    padded_sequence = pad_sequences(sequence, maxlen=X_train_padded.shape[1])
    return padded_sequence

# Fungsi untuk memprediksi kerusakan
def predict_damage():
    selected_gejala = [gejala[i] for i, var in enumerate(checkbox_vars) if var.get() == 1]

    # Hanya memproses jika ada gejala yang dipilih
    if selected_gejala:
        # Maksimal 3 gejala yang dicentang
        selected_gejala = selected_gejala[:3]

        # Mengonversi teks menjadi sequence
        input_text = ' '.join(selected_gejala)
        input_sequence = text_to_sequence(input_text)

        # Melakukan prediksi
        prediction = model.predict(input_sequence)

        # Mengambil indeks label dengan probabilitas tertinggi
        predicted_category_index = prediction.argmax(axis=1)[0]

        # Mendapatkan nama kategori berdasarkan indeks
        predicted_category = list(label_to_index.keys())[list(label_to_index.values()).index(predicted_category_index)]

        # Menampilkan hasil prediksi
        result_label.config(text=f"Kemungkinan Kerusakan: {predicted_category}")
    else:
        result_label.config(text="Silakan pilih setidaknya satu gejala.")

# %%
# Membuat GUI
root = tk.Tk()
root.title("Deteksi Kerusakan Sepeda Motor")

# List untuk menyimpan variabel checkbox
checkbox_vars = []

# Membuat checkbox untuk setiap gejala
gejala = df['gejala']
num_gejala = len(gejala)

# Menentukan jumlah kolom
num_cols = 2
# Menentukan jumlah baris (dibulatkan ke atas agar cukup untuk semua gejala)
num_rows = -(-num_gejala // num_cols)

for i, g in enumerate(gejala):
    var = tk.IntVar()
    checkbox = ttk.Checkbutton(root, text=g, variable=var)
    # Menentukan posisi baris dan kolom
    checkbox.grid(row=i // num_cols, column=i % num_cols, sticky="w", padx=10, pady=5)
    checkbox_vars.append(var)

# Tombol untuk memprediksi kerusakan
predict_button = ttk.Button(root, text="Prediksi Kerusakan", command=predict_damage)
# Menentukan posisi tombol pada baris setelah checkbox
predict_button.grid(row=num_rows, column=0, columnspan=num_cols, pady=10)

# Label untuk menampilkan hasil prediksi
result_label = ttk.Label(root, text="")
# Menentukan posisi label pada baris setelah tombol
result_label.grid(row=num_rows + 1, column=0, columnspan=num_cols, pady=5)

# Menjalankan GUI
root.mainloop()
# Out:
# 1/1 [==============================] - 1s 610ms/step
